# %%
# import all the things
import pandas as pd
from sqlalchemy import create_engine

# %%
# path to Golden Globes csv file
gg_file = "Resources/golden_globe_awards.csv"

# read in Golden Globes csv file
gg_df = pd.read_csv(gg_file)
gg_df.head()
# Out:
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                       film   win
# 0  For Whom The Bell Tolls  True
# 1  For Whom The Bell Tolls  True
# 2   The Song Of Bernadette  True
# 3                      NaN  True
# 4   The Song Of Bernadette  True

# %%
# drop unnecessary columns ceremony and year_film
new_gg_df = gg_df.drop(columns={"ceremony","year_film"})
new_gg_df.head()
# Out:
#    year_award                                           category  \
# 0        1944  Best Performance by an Actress in a Supporting...
# 1        1944  Best Performance by an Actor in a Supporting R...
# 2        1944                     Best Director - Motion Picture
# 3        1944                                            Picture
# 4        1944                          Actress In A Leading Role
#
#                   nominee                     film   win
# 0          Katina Paxinou  For Whom The Bell Tolls  True
# 1           Akim Tamiroff  For Whom The Bell Tolls  True
# 2              Henry King   The Song Of Bernadette  True
# 3  The Song Of Bernadette                      NaN  True
# 4          Jennifer Jones   The Song Of Bernadette  True

# %%
# remove non movie based categories
movies_only = new_gg_df[new_gg_df['category'].str.contains('Actor') == False]
movies_only = movies_only[movies_only['category'].str.contains('Actress') == False]
movies_only = movies_only[movies_only['category'].str.contains('Director') == False]
movies_only = movies_only[movies_only['category'].str.contains('International') == False]
movies_only = movies_only[movies_only['category'].str.contains('Special') == False]
movies_only = movies_only[movies_only['category'].str.contains('Screenplay') == False]
movies_only = movies_only[movies_only['category'].str.contains('Song') == False]
movies_only = movies_only[movies_only['category'].str.contains('Score') == False]
movies_only = movies_only[movies_only['category'].str.contains('Cinematography') == False]
movies_only = movies_only[movies_only['category'].str.contains('Foreign') == False]
movies_only = movies_only[movies_only['category'].str.contains('Star') == False]
movies_only = movies_only[movies_only['category'].str.contains('Juvenile') == False]
movies_only = movies_only[movies_only['category'].str.contains('International') == False]
movies_only = movies_only[movies_only['category'].str.contains('Color') == False]
movies_only = movies_only[movies_only['category'].str.contains('Henrietta') == False]
movies_only = movies_only[movies_only['category'].str.contains('Cecil') == False]
movies_only = movies_only[movies_only['category'].str.contains('International') == False]
movies_only = movies_only[movies_only['category'].str.contains('Documentary') == False]
movies_only = movies_only[movies_only['category'].str.contains('Television') == False]
movies_only = movies_only[movies_only['category'].str.contains('Hollywood') == False]


# drop film column and rename nominee column to film
movies_only = movies_only.drop(columns="film")
movies_only = movies_only.rename(columns={"nominee":"film"})

# %%
movies_only.head(50)
# Out:
#      year_award                                 category  \
# 3          1944                                  Picture
# 9          1945                                  Picture
# 16         1946                                  Picture
# 24         1947                                  Picture
# 35         1948                                  Picture
# 46         1949                                  Picture
# 47         1949                                  Picture
# 73         1950                                  Picture
# 74         1950                                  Picture
# 112        1951                                  Picture
# 113        1951                                  Picture
# 114        1951                                  Picture
# 126        1952              Best Motion Picture - Drama
# 127        1952              Best Motion Picture - Drama
# 128        1952              Best Motion Picture - Drama
# 129        1952              Best Motion Picture - Drama
# 130        1952              Best Motion Picture - Drama
# 131        1952  Best Motion Picture - Musical or Comedy
# 163        1953              Best Motion Picture - Drama
# 164        1953              Best Motion Picture - Drama
# 165        1953              Best Motion Picture - Drama
# 166        1953              Best Motion Picture - Drama
# 167        1953              Best Motion Picture - Drama
# 168        1953  Best Motion Picture - Musical or Comedy
# 169        1953  Best Motion Picture - Musical or Comedy
# 170        1953  Best Motion Picture - Musical or Comedy
# 171        1953  Best Motion Picture - Musical or Comedy
# 172        1953  Best Motion Picture - Musical or Comedy
# 222        1954              Best Motion Picture - Drama
# 250        1955              Best Motion Picture - Drama
# 251        1955  Best Motion Picture - Musical or Comedy
# 281        1956              Best Motion Picture - Drama
# 282        1956  Best Motion Picture - Musical or Comedy
# 308        1957              Best Motion Picture - Drama
# 309        1957              Best Motion Picture - Drama
# 310        1957              Best Motion Picture - Drama
# 311        1957              Best Motion Picture - Drama
# 312        1957              Best Motion Picture - Drama
# 313        1957  Best Motion Picture - Musical or Comedy
# 314        1957  Best Motion Picture - Musical or Comedy
# 315        1957  Best Motion Picture - Musical or Comedy
# 316        1957  Best Motion Picture - Musical or Comedy
# 317        1957  Best Motion Picture - Musical or Comedy
# 386        1958              Best Motion Picture - Drama
# 387        1958              Best Motion Picture - Drama
# 388        1958              Best Motion Picture - Drama
# 389        1958              Best Motion Picture - Drama
# 390        1958              Best Motion Picture - Drama
# 391        1958  Best Motion Picture - Musical or Comedy
# 392        1958  Best Motion Picture - Musical or Comedy
#
#                                  film    win
# 3              The Song Of Bernadette   True
# 9                        Going My Way   True
# 16                   The Lost Weekend   True
# 24        The Best Years Of Our Lives   True
# 35              Gentleman's Agreement   True
# 46                     Johnny Belinda   True
# 47   The Treasure of the Sierra Madre   True
# 73                 All The King's Men   True
# 74                 Come To The Stable  False
# 112                  Sunset Boulevard   True
# 113                    Born Yesterday  False
# 114         Cyrano de Bergerac (1950)  False
# 126                A Place In The Sun   True
# 127                        Quo Vadis?  False
# 128   A Streetcar Named Desire (1951)  False
# 129                    Bright Victory  False
# 130                   Detective Story  False
# 131              An American In Paris   True
# 163        The Greatest Show On Earth   True
# 164           Come Back, Little Sheba  False
# 165                    The Happy Time  False
# 166                         High Noon  False
# 167                         The Thief  False
# 168           With a Song in My Heart   True
# 169           Hans Christian Andersen  False
# 170         I'll See You in My Dreams  False
# 171               Singin' in the Rain  False
# 172          Star and Stripes Forever  False
# 222                         Robe, The   True
# 250                 On the Waterfront   True
# 251                      Carmen Jones   True
# 281                      East of Eden   True
# 282                    Guys and Dolls   True
# 308       Around the World in 80 Days   True
# 309                     Lust For Life  False
# 310                    Rainmaker, The  False
# 311                     War and Peace  False
# 312                             Giant  False
# 313                   King and I, The   True
# 314                          Bus Stop  False
# 315                 Opposite Sex, The  False
# 316          Solid Gold Cadillac, The  False
# 317  Teahouse of the August Moon, The  False
# 386     Bridge on the River Kwai, The   True
# 387               12 Angry Men (1957)  False
# 388                  Wild is the Wind  False
# 389       Witness for the Prosecution  False
# 390                          Sayonara  False
# 391                         Les Girls   True
# 392           Don't Go Near The Water  False

# %%
# read the movie title list into a column for cleaning
movie_title_list = movies_only["film"].tolist()
# Out:
# ['The Song Of Bernadette', 'Going My Way', 'The Lost Weekend', 'The Best Years Of Our Lives', "Gentleman's Agreement", 'Johnny Belinda', 'The Treasure of the Sierra Madre', "All The King's Men", 'Come To The Stable', 'Sunset Boulevard', 'Born Yesterday', 'Cyrano de Bergerac (1950)', 'A Place In The Sun', 'Quo Vadis?', 'A Streetcar Named Desire (1951)', 'Bright Victory', 'Detective Story', 'An American In Paris', 'The Greatest Show On Earth', 'Come Back, Little Sheba', 'The Happy Time', 'High Noon', 'The Thief', 'With a Song in My Heart', 'Hans Christian Andersen', "I'll See You in My Dreams", "Singin' in the Rain", 'Star and Stripes Forever', 'Robe, The', 'On the Waterfront', 'Carmen Jones', 'East of Eden', 'Guys and Dolls', 'Around the World in 80 Days', 'Lust For Life', 'Rainmaker, The', 'War and Peace', 'Giant', 'King and I, The', 'Bus Stop', 'Opposite Sex, The', 'Solid Gold Cadillac, The', 'Teahouse of the August Moon, The', 'Bridge on the River Kwai, The', '12 Angry Men (1957)', 'Wild is the Wind', 'Witness for the Prosecution', 'Sayonara', 'Les Girls', "Don't Go Near The Water", 'Love in the Afternoon', 'Pal Joey', 'Silk Stockings', 'Defiant Ones, The', 'Home Before Dark', 'I Want To Live!', 'Separate Tables', 'Cat on a Hot Tin Roof', 'Gigi', 'Damn Yankees', 'Tom Thumb', 'Auntie Mame', 'The Perfect Furlough', 'Bell, Book and Candle', 'Indiscreet', 'Me and the Colonel', 'Ben-Hur', 'Anatomy of a Murder', 'Diary of Anne Frank, The', "Nun's Story, The", 'On The Beach', 'Ramon Novarro', 'Porgy and Bess', 'Five Pennies, The', "Li'l Abner", "Private's Affair, A", 'Say One For Me', 'Some Like It Hot', 'But Not For Me', 'Operation Petticoat', 'Pillow Talk', 'Who Was That Lady?', 'Spartacus', 'Elmer Gantry', 'Inherit the Wind - 1960', 'Sons and Lovers', 'Sunrise at Campobello', 'Song Without End ', 'Bells Are Ringing', 'Walter Lang', 'Jerry Wald', 'George Sidney', 'Apartment, The', 'Our Man in Havana', 'Facts of Life, The', 'Grass is Greener, The', 'It Started in Naples', 'The Guns Of Navarone', 'El Cid', 'Fanny', 'Judgment at Nuremberg', 'Splendor in the Grass', 'West Side Story', 'Flower Drum Song', 'A Majority Of One', "Breakfast at Tiffany's", 'One, Two, Three', 'Pocketful of Miracles', 'Lawrence Of Arabia', 'Days of Wine and Roses', 'Freud', 'Lisa', 'Longest Day, The', 'Miracle Worker, The', 'Mutiny on the Bounty', 'To Kill A Mockingbird', "Hemingway's Adventures of a Young Man", 'Chapman Report, The', "Meredith Willson's The Music Man", "Billy Rose's Jumbo", 'The Wonderful World Of The Brothers Grimm', 'That Touch of Mink', 'The Best Of Enemies', "Boys' Night Out", 'If a Man Answers', 'Period of Adjustment', 'Cardinal, The', 'America, America', 'Captain Newman, M.D.', 'Caretakers, The', 'Cleopatra', 'Great Escape, The', 'Hud', 'Lilies of the Field', 'Tom Jones', 'Ticklish Affair, A', 'Under The Yum Yum Tree', 'Bye Bye Birdie', 'Irma La Douce', "It's a Mad, Mad, Mad, Mad World", 'Becket', 'Chalk Garden, The', 'Dear Heart', 'Night of the Iguana, The', 'Zorba The Greek', 'My Fair Lady', 'Mary Poppins', 'Unsinkable Molly Brown, The', 'World of Henry Orient, The', 'Father Goose', 'Doctor Zhivago', 'Collector, The', 'Flight of the Phoenix, The', 'Patch of Blue, A', 'Ship of Fools', 'Sound of Music, The', 'Cat Ballou', 'The Great Race', 'Those Magnificent Men in Their Flying Machines', 'Thousand Clowns, A', 'Man for All Seasons, A', 'Born Free', 'Professionals, The', 'The Sand Pebbles', "Who's Afraid of Virginia Woolf?", 'Russians Are Coming, The Russians Are Coming, The', 'Funny Thing Happened on the Way to the Forum, A', 'Gambit', "Not With My Wife, You Don't", "You're a Big Boy Now", 'In the Heat of the Night', 'Bonnie and Clyde', 'Far From The Madding Crowd', "Guess Who's Coming To Dinner", 'In Cold Blood', 'Graduate, The', 'Camelot', 'Doctor Dolittle', 'Taming of the Shrew, The', 'Thoroughly Modern Millie', 'The Lion in Winter', 'Charly', 'Fixer, The', 'Heart Is a Lonely Hunter, The', 'Shoes of the Fisherman, The', 'Oliver!',  ...

# %%
# remove any "The" at the start of the movie name
# remove any ", The" at the end of the movie name
for i in range(0, len(movie_title_list)):
    if movie_title_list[i][-5:] == ", The":
        movie_title_list[i] = movie_title_list[i][:-5]
    if movie_title_list[i][:4] == "The ":
        movie_title_list[i] = movie_title_list[i][4:]

# %%
# rename film to old film title
movies_only = movies_only.rename(columns={"film":"old_film_title"})

# add cleaned film title to data frame
movies_only["film"] = movie_title_list
